# %% [markdown]
# # Exercises
# The end result of this exercise should be a file named prepare.py.

# %%
# tabular data manipulation
import numpy as np
import pandas as pd
# datetime utilities
from datetime import timedelta, datetime
import datetime
# visualization
import matplotlib.pyplot as plt

# no yelling in the library
import warnings
warnings.filterwarnings("ignore")

import acquire

# %% [markdown]
# # Using your store items data:
#
# ## 1. Convert date column to datetime format.
# ## 2. Plot the distribution of sale_amount and item_price.
# ## 3. Set the index to be the datetime variable.
# ## 4. Add a 'month' and 'day of week' column to your dataframe.
# ## 5.Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.
# ## 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
## 1. Convert date column to datetime format.

# %%
#Bring in store data and convert to dataframe
df= acquire.combined_dataframes()

# %%
df.head()
# Out:
#    Unnamed: 0_x  item  sale_amount                      sale_date  sale_id  \
# 0             0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1
# 1             1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2
# 2             2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3
# 3             3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4
# 4             4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5
#
#    store  Unnamed: 0_y           store_address   store_city  store_id  \
# 0      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 1      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 2      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 3      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 4      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
#
#   store_state  store_zipcode  Unnamed: 0 item_brand  item_id  \
# 0          TX          78253           0   Riceland        1
# 1          TX          78253           0   Riceland        1
# 2          TX          78253           0   Riceland        1
# 3          TX          78253           0   Riceland        1
# 4          TX          78253           0   Riceland        1
#
#                         item_name  item_price   item_upc12   item_upc14
# 0  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 1  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 2  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 3  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 4  Riceland American Jazmine Rice        0.84  35200264013  35200264013

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913000 entries, 0 to 912999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0_x   913000 non-null  int64
#  1   item           913000 non-null  int64
#  2   sale_amount    913000 non-null  float64
#  3   sale_date      913000 non-null  object
#  4   sale_id        913000 non-null  int64
#  5   store          913000 non-null  int64
#  6   Unnamed: 0_y   913000 non-null  int64
#  7   store_address  913000 non-null  object
#  8   store_city     913000 non-null  object
#  9   store_id       913000 non-null  int64
#  10  store_state    913000 non-null  object
#  11  store_zipcode  913000 non-null  int64
#  12  Unnamed: 0     913000 non-null  int64
#  13  item_brand     913000 non-null  object
#  14  item_id        913000 non-null  int64
#  15  item_name      913000 non-null  object
#  16  item_price     913000 non-null  float64
#  17  item_upc12     913000 non-null  int64
#  18  item_upc14     913000 non-null  int64
# dtypes: float64(2), int64(11), object(6)
# memory usage: 139.3+ MB

# %%
#drop columns
df= df.drop(columns= ['Unnamed: 0_x', 'Unnamed: 0_y', 'Unnamed: 0'])

# %%
#Changing sale amount datatype to datatime64 object
df.sale_amount= pd.to_datetime(df.sale_amount)

# %%
# Verifying datatype was changed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913000 entries, 0 to 912999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item           913000 non-null  int64
#  1   sale_amount    913000 non-null  datetime64[ns]
#  2   sale_date      913000 non-null  object
#  3   sale_id        913000 non-null  int64
#  4   store          913000 non-null  int64
#  5   store_address  913000 non-null  object
#  6   store_city     913000 non-null  object
#  7   store_id       913000 non-null  int64
#  8   store_state    913000 non-null  object
#  9   store_zipcode  913000 non-null  int64
#  10  item_brand     913000 non-null  object
#  11  item_id        913000 non-null  int64
#  12  item_name      913000 non-null  object
#  13  item_price     913000 non-null  float64
#  14  item_upc12     913000 non-null  int64
#  15  item_upc14     913000 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(8), object(6)
# memory usage: 118.4+ MB

# %%
## 2. Plot the distribution of sale_amount and item_price.plot.
plt.figure()
df.sale_amount.hist(label= "Sale Amount")
plt.title('Plot of Sale Amount')
plt.legend()
plt.show()

# %%
plt.figure()
df.item_price.hist(label= "Item Price")
plt.title('Plot of Item Price')
plt.legend()
plt.show()

# %%
## 3. Set the index to be the datetime variable.
df.set_index('sale_date')
# Out:
#                                item                   sale_amount  sale_id  \
# sale_date
# Tue, 01 Jan 2013 00:00:00 GMT     1 1970-01-01 00:00:00.000000013        1
# Wed, 02 Jan 2013 00:00:00 GMT     1 1970-01-01 00:00:00.000000011        2
# Thu, 03 Jan 2013 00:00:00 GMT     1 1970-01-01 00:00:00.000000014        3
# Fri, 04 Jan 2013 00:00:00 GMT     1 1970-01-01 00:00:00.000000013        4
# Sat, 05 Jan 2013 00:00:00 GMT     1 1970-01-01 00:00:00.000000010        5
# ...                             ...                           ...      ...
# Wed, 27 Dec 2017 00:00:00 GMT    50 1970-01-01 00:00:00.000000063   912996
# Thu, 28 Dec 2017 00:00:00 GMT    50 1970-01-01 00:00:00.000000059   912997
# Fri, 29 Dec 2017 00:00:00 GMT    50 1970-01-01 00:00:00.000000074   912998
# Sat, 30 Dec 2017 00:00:00 GMT    50 1970-01-01 00:00:00.000000062   912999
# Sun, 31 Dec 2017 00:00:00 GMT    50 1970-01-01 00:00:00.000000082   913000
#
#                                store           store_address   store_city  \
# sale_date
# Tue, 01 Jan 2013 00:00:00 GMT      1  12125 Alamo Ranch Pkwy  San Antonio
# Wed, 02 Jan 2013 00:00:00 GMT      1  12125 Alamo Ranch Pkwy  San Antonio
# Thu, 03 Jan 2013 00:00:00 GMT      1  12125 Alamo Ranch Pkwy  San Antonio
# Fri, 04 Jan 2013 00:00:00 GMT      1  12125 Alamo Ranch Pkwy  San Antonio
# Sat, 05 Jan 2013 00:00:00 GMT      1  12125 Alamo Ranch Pkwy  San Antonio
# ...                              ...                     ...          ...
# Wed, 27 Dec 2017 00:00:00 GMT     10    8503 NW Military Hwy  San Antonio
# Thu, 28 Dec 2017 00:00:00 GMT     10    8503 NW Military Hwy  San Antonio
# Fri, 29 Dec 2017 00:00:00 GMT     10    8503 NW Military Hwy  San Antonio
# Sat, 30 Dec 2017 00:00:00 GMT     10    8503 NW Military Hwy  San Antonio
# Sun, 31 Dec 2017 00:00:00 GMT     10    8503 NW Military Hwy  San Antonio
#
#                                store_id store_state  store_zipcode item_brand  \
# sale_date
# Tue, 01 Jan 2013 00:00:00 GMT         1          TX          78253   Riceland
# Wed, 02 Jan 2013 00:00:00 GMT         1          TX          78253   Riceland
# Thu, 03 Jan 2013 00:00:00 GMT         1          TX          78253   Riceland
# Fri, 04 Jan 2013 00:00:00 GMT         1          TX          78253   Riceland
# Sat, 05 Jan 2013 00:00:00 GMT         1          TX          78253   Riceland
# ...                                 ...         ...            ...        ...
# Wed, 27 Dec 2017 00:00:00 GMT        10          TX          78231     Choice
# Thu, 28 Dec 2017 00:00:00 GMT        10          TX          78231     Choice
# Fri, 29 Dec 2017 00:00:00 GMT        10          TX          78231     Choice
# Sat, 30 Dec 2017 00:00:00 GMT        10          TX          78231     Choice
# Sun, 31 Dec 2017 00:00:00 GMT        10          TX          78231     Choice
#
#                                item_id  \
# sale_date
# Tue, 01 Jan 2013 00:00:00 GMT        1
# Wed, 02 Jan 2013 00:00:00 GMT        1
# Thu, 03 Jan 2013 00:00:00 GMT        1
# Fri, 04 Jan 2013 00:00:00 GMT        1
# Sat, 05 Jan 2013 00:00:00 GMT        1
# ...                                ...
# Wed, 27 Dec 2017 00:00:00 GMT       50
# Thu, 28 Dec 2017 00:00:00 GMT       50
# Fri, 29 Dec 2017 00:00:00 GMT       50
# Sat, 30 Dec 2017 00:00:00 GMT       50
# Sun, 31 Dec 2017 00:00:00 GMT       50
#
#                                                                        item_name  \
# sale_date
# Tue, 01 Jan 2013 00:00:00 GMT                     Riceland American Jazmine Rice
# Wed, 02 Jan 2013 00:00:00 GMT                     Riceland American Jazmine Rice
# Thu, 03 Jan 2013 00:00:00 GMT                     Riceland American Jazmine Rice
# Fri, 04 Jan 2013 00:00:00 GMT                     Riceland American Jazmine Rice
# Sat, 05 Jan 2013 00:00:00 GMT                     Riceland American Jazmine Rice
# ...                                                                          ...
# Wed, 27 Dec 2017 00:00:00 GMT  Choice Organic Teas Black Tea Classic Black - ...
# Thu, 28 Dec 2017 00:00:00 GMT  Choice Organic Teas Black Tea Classic Black - ...
# Fri, 29 Dec 2017 00:00:00 GMT  Choice Organic Teas Black Tea Classic Black - ...
# Sat, 30 Dec 2017 00:00:00 GMT  Choice Organic Teas Black Tea Classic Black - ...
# Sun, 31 Dec 2017 00:00:00 GMT  Choice Organic Teas Black Tea Classic Black - ...
#
#                                item_price   item_upc12   item_upc14
# sale_date
# Tue, 01 Jan 2013 00:00:00 GMT        0.84  35200264013  35200264013
# Wed, 02 Jan 2013 00:00:00 GMT        0.84  35200264013  35200264013
# Thu, 03 Jan 2013 00:00:00 GMT        0.84  35200264013  35200264013
# Fri, 04 Jan 2013 00:00:00 GMT        0.84  35200264013  35200264013
# Sat, 05 Jan 2013 00:00:00 GMT        0.84  35200264013  35200264013
# ...                                   ...          ...          ...
# Wed, 27 Dec 2017 00:00:00 GMT        5.20  47445919221  47445919221
# Thu, 28 Dec 2017 00:00:00 GMT        5.20  47445919221  47445919221
# Fri, 29 Dec 2017 00:00:00 GMT        5.20  47445919221  47445919221
# Sat, 30 Dec 2017 00:00:00 GMT        5.20  47445919221  47445919221
# Sun, 31 Dec 2017 00:00:00 GMT        5.20  47445919221  47445919221
#
# [913000 rows x 15 columns]

# %%
## 4. Add a 'month' and 'day of week' column to your dataframe.
# df['day'] = df.day_name()

# %%
df['month']= df.index.

# %%
## 5.Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
## 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# # Part II
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %% [markdown]
# # 1. Convert date column to datetime format.

# %% [markdown]
# # 2. Plot the distribution of each of your variables.

# %% [markdown]
# # 3. Set the index to be the datetime variable.

# %% [markdown]
# # 4. Add a month and a year column to your dataframe.

# %% [markdown]
# # 5. Fill any missing values.

# %% [markdown]
# # 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
