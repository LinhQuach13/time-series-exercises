# %% [markdown]
# # Exercises
# The end result of this exercise should be a file named prepare.py.

# %%
# tabular data manipulation
import numpy as np
import pandas as pd
# datetime utilities
from datetime import timedelta, datetime
import datetime
# visualization
import matplotlib.pyplot as plt

# no yelling in the library
import warnings
warnings.filterwarnings("ignore")

import acquire
import prepare

# %% [markdown]
# # Using your store items data:
#
# ## 1. Convert date column to datetime format.
# ## 2. Plot the distribution of sale_amount and item_price.
# ## 3. Set the index to be the datetime variable.
# ## 4. Add a 'month' and 'day of week' column to your dataframe.
# ## 5.Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.
# ## 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
## 1. Convert date column to datetime format.

# %%
#Bring in store data and convert to dataframe
df= acquire.combined_dataframes()

# %%
df.head()
# Out:
#    Unnamed: 0_x  item  sale_amount                      sale_date  sale_id  \
# 0             0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1
# 1             1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2
# 2             2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3
# 3             3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4
# 4             4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5
#
#    store  Unnamed: 0_y           store_address   store_city  store_id  \
# 0      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 1      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 2      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 3      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
# 4      1             0  12125 Alamo Ranch Pkwy  San Antonio         1
#
#   store_state  store_zipcode  Unnamed: 0 item_brand  item_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913000 entries, 0 to 912999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0_x   913000 non-null  int64
#  1   item           913000 non-null  int64
#  2   sale_amount    913000 non-null  float64
#  3   sale_date      913000 non-null  object
#  4   sale_id        913000 non-null  int64
#  5   store          913000 non-null  int64
#  6   Unnamed: 0_y   913000 non-null  int64
#  7   store_address  913000 non-null  object
#  8   store_city     913000 non-null  object
#  9   store_id       913000 non-null  int64
#  10  store_state    913000 non-null  object
#  11  store_zipcode  913000 non-null  int64
#  12  Unnamed: 0     913000 non-null  int64
#  13  item_brand     913000 non-null  object
#  14  item_id        913000 non-null  int64
#  15  item_name      913000 non-null  object
#  16  item_price     913000 non-null  float64
# ...

# %%
#drop columns
df= prepare.drop_cols(df)

# %%
df.head()
# Out:
#    item  sale_amount                      sale_date  sale_id  store  \
# 0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
#
#             store_address   store_city  store_id store_state  store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 1  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 2  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 3  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 4  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
#
#   item_brand  item_id                       item_name  item_price  \
# ...

# %%
#Changing sale date datatype to datatime64 object
prepare.datatype_datatime64(df)
# Out:
#         item  sale_amount                 sale_date  sale_id  store  \
# 0          1         13.0 2013-01-01 00:00:00+00:00        1      1
# 1          1         11.0 2013-01-02 00:00:00+00:00        2      1
# 2          1         14.0 2013-01-03 00:00:00+00:00        3      1
# 3          1         13.0 2013-01-04 00:00:00+00:00        4      1
# 4          1         10.0 2013-01-05 00:00:00+00:00        5      1
# ...      ...          ...                       ...      ...    ...
# 912995    50         63.0 2017-12-27 00:00:00+00:00   912996     10
# 912996    50         59.0 2017-12-28 00:00:00+00:00   912997     10
# 912997    50         74.0 2017-12-29 00:00:00+00:00   912998     10
# 912998    50         62.0 2017-12-30 00:00:00+00:00   912999     10
# 912999    50         82.0 2017-12-31 00:00:00+00:00   913000     10
#
#                  store_address   store_city  store_id store_state  \
# 0       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# ...

# %%
# Verifying datatype was changed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913000 entries, 0 to 912999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item           913000 non-null  int64
#  1   sale_amount    913000 non-null  float64
#  2   sale_date      913000 non-null  datetime64[ns, UTC]
#  3   sale_id        913000 non-null  int64
#  4   store          913000 non-null  int64
#  5   store_address  913000 non-null  object
#  6   store_city     913000 non-null  object
#  7   store_id       913000 non-null  int64
#  8   store_state    913000 non-null  object
#  9   store_zipcode  913000 non-null  int64
#  10  item_brand     913000 non-null  object
#  11  item_id        913000 non-null  int64
#  12  item_name      913000 non-null  object
#  13  item_price     913000 non-null  float64
#  14  item_upc12     913000 non-null  int64
#  15  item_upc14     913000 non-null  int64
# ...

# %%
## 2. Plot the distribution of sale_amount and item_price.plot.

#plot sale_amount
prepare.plot_sale_amount(df)

# %%
#Plot item_price plot
prepare.plot_item_price(df)

# %%
## 3. Set the index to be the datetime variable.
df= prepare.set_store_index(df)

# %%
df.head()
# Out:
#                            item  sale_amount  sale_id  store  \
# sale_date
# 2013-01-01 00:00:00+00:00     1         13.0        1      1
# 2013-01-01 00:00:00+00:00    12         26.0   211817      7
# 2013-01-01 00:00:00+00:00    46         27.0   832657      7
# 2013-01-01 00:00:00+00:00    12         54.0   213643      8
# 2013-01-01 00:00:00+00:00    12         35.0   215469      9
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio         9
#
#                           store_state  store_zipcode  item_brand  item_id  \
# sale_date
# ...

# %%
## 4. Add a 'month' and 'day of week' column to your dataframe

# %%
## 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
prepare.month_day_and_sales_col(df)
# Out:
#                            item  sale_amount  sale_id  store  \
# sale_date
# 2013-01-01 00:00:00+00:00     1         13.0        1      1
# 2013-01-01 00:00:00+00:00    12         26.0   211817      7
# 2013-01-01 00:00:00+00:00    46         27.0   832657      7
# 2013-01-01 00:00:00+00:00    12         54.0   213643      8
# 2013-01-01 00:00:00+00:00    12         35.0   215469      9
# ...                         ...          ...      ...    ...
# 2017-12-31 00:00:00+00:00    34         21.0   619014      9
# 2017-12-31 00:00:00+00:00    34         32.0   620840     10
# 2017-12-31 00:00:00+00:00    35         55.0   622666      1
# 2017-12-31 00:00:00+00:00    33        100.0   598928      8
# 2017-12-31 00:00:00+00:00    50         82.0   913000     10
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# ...

# %%
#Verify day column was added
df.head()
# Out:
#                            item  sale_amount  sale_id  store  \
# sale_date
# 2013-01-01 00:00:00+00:00     1         13.0        1      1
# 2013-01-01 00:00:00+00:00    12         26.0   211817      7
# 2013-01-01 00:00:00+00:00    46         27.0   832657      7
# 2013-01-01 00:00:00+00:00    12         54.0   213643      8
# 2013-01-01 00:00:00+00:00    12         35.0   215469      9
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio         9
#
#                           store_state  store_zipcode  item_brand  item_id  \
# sale_date
# ...

# %%
# 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into 
# separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# ### Answer: Please refer to prepare.py file for functions

# %% [markdown]
# # Part II
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %% [markdown]
# # 1. Convert date column to datetime format.

# %%
germany_df= acquire.get_germany_data("https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv", cached=False)

# %%
germany_df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
#Looking at datatypes for conversion
germany_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   object
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %%
#Changing date datatype to datatime64 object
germany_df.Date= pd.to_datetime(germany_df.Date)

# %%
#Looking at datatypes after conversion
germany_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %% [markdown]
# # 2. Plot the distribution of each of your variables.

# %%
# Plot of consumption
plt.figure()
germany_df.Consumption.hist(label= "Consumption")
plt.title('Distribution of Consumption')
plt.legend()
plt.show()

# %%
# Plot of Wind
plt.figure()
germany_df.Wind.hist(label= "Wind")
plt.title('Distribution of Wind')
plt.legend()
plt.show()

# %%
# Plot of Solar
plt.figure()
germany_df.Solar.hist(label= "Solar")
plt.title('Distribution of Solar')
plt.legend()
plt.show()

# %%
# Plot of Wind+Solar
plt.figure()
germany_df['Wind+Solar'].hist(label= "Wind and Solar")
plt.title('Distribution of Wind + Solar')
plt.legend()
plt.show()

# %% [markdown]
# # 3. Set the index to be the datetime variable.

# %%
germany_df= germany_df.set_index('Date').sort_index()

# %% [markdown]
# # 4. Add a month and a year column to your dataframe.

# %%
#Adding month column
germany_df['month'] = germany_df.index.month

# %%
# Verify new month column was added
germany_df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN      1
# 2006-01-02     1380.521   NaN    NaN         NaN      1
# 2006-01-03     1442.533   NaN    NaN         NaN      1
# 2006-01-04     1457.217   NaN    NaN         NaN      1
# 2006-01-05     1477.131   NaN    NaN         NaN      1

# %%
#Creating year column
germany_df['year'] = germany_df.index.year

# %%
#Verify year column added
germany_df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month  year
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN      1  2006
# 2006-01-02     1380.521   NaN    NaN         NaN      1  2006
# 2006-01-03     1442.533   NaN    NaN         NaN      1  2006
# 2006-01-04     1457.217   NaN    NaN         NaN      1  2006
# 2006-01-05     1477.131   NaN    NaN         NaN      1  2006

# %% [markdown]
# # 5. Fill any missing values.

# %%
germany_df = germany_df.fillna(value=0)

# %%
germany_df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month  year
# Date
# 2006-01-01     1069.184   0.0    0.0         0.0      1  2006
# 2006-01-02     1380.521   0.0    0.0         0.0      1  2006
# 2006-01-03     1442.533   0.0    0.0         0.0      1  2006
# 2006-01-04     1457.217   0.0    0.0         0.0      1  2006
# 2006-01-05     1477.131   0.0    0.0         0.0      1  2006

# %% [markdown]
# # 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
# Loading in copy of germany data to run in function
germany_copy= acquire.get_germany_data("https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv", cached=False)

# %%
def prepare_germany_data(df):
    ''' 
    Prepare Germany Data
    '''
    #Changing date datatype to datatime64 object
    df.Date= pd.to_datetime(df.Date)
    # Plot of consumption
    plt.figure()
    df.Consumption.hist(label= "Consumption")
    plt.title('Distribution of Consumption')
    plt.legend()
    plt.show()
    # Plot of Wind
    plt.figure()
    df.Wind.hist(label= "Wind")
    plt.title('Distribution of Wind')
    plt.legend()
    plt.show()
    # Plot of Solar
    plt.figure()
    df.Solar.hist(label= "Solar")
    plt.title('Distribution of Solar')
    plt.legend()
    plt.show()
    # Plot of Wind+Solar
    plt.figure()
    df['Wind+Solar'].hist(label= "Wind and Solar")
    plt.title('Distribution of Wind + Solar')
    plt.legend()
    plt.show()
    #Set the index to be the datetime variable.
    df= df.set_index('Date').sort_index()
    #Adding month column
    df['month'] = df.index.month
    #Creating year column
    df['year'] = df.index.year
    #Fill any missing values
    df = df.fillna(value=0)
    return df

# %%
# verify function works
prepare_germany_data(germany_copy)
# Out:
#             Consumption     Wind   Solar  Wind+Solar  month  year
# Date
# 2006-01-01   1069.18400    0.000   0.000       0.000      1  2006
# 2006-01-02   1380.52100    0.000   0.000       0.000      1  2006
# 2006-01-03   1442.53300    0.000   0.000       0.000      1  2006
# 2006-01-04   1457.21700    0.000   0.000       0.000      1  2006
# 2006-01-05   1477.13100    0.000   0.000       0.000      1  2006
# ...                 ...      ...     ...         ...    ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037     12  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586     12  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131     12  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714     12  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156     12  2017
#
# [4383 rows x 6 columns]
